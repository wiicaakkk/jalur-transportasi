# %% [markdown]
# Bagus Wicaksono Nurjayanto - 1301194280 - IF42GAB03

# %% [markdown]
# # Rute Angkutan Umum Kota Bandung
# via : http://dishub.jabarprov.go.id/angkutan/kabkota/301.html

# %%
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({
    'from': [
        'Kebon Kelapa', 'Kebon Kelapa', 'Kebon Kelapa', 'Kebon Kelapa', 'Cibaduyut', 'Cicaheum',  'Cicaheum', 'Cicaheum', 'Ciroyom', 'Ciroyom', 'Ciroyom', 'Ciroyom', 'Dago', 'Dago', 'Margahayu Raya', 'Panghegar Permai', 'Sadang Serang', 'Sadang Serang', 'St Hall', 'St Hall', 'Stasiun Hall', 'Stasiun Hall', 'Stasiun Hall', 'Stasiun Hall', 'Stasiun Hall'

    ],
    'to': [
        'Cicaheum', 'Cicaheum (aceh)', 'Dago', 'Ledeng', 'Kebon Kelapa', 'Ciroyom', 'Ledeng', 'Leuwipanjang', 'Bumi Asri', 'Sarijadi', 'Sarijadi ', 'Bumi Asri', 'Pasar lnduk Caringin', 'Riung Bandung', 'Ledeng', 'Dipatiukur', 'Caringin', 'Caringin', 'Dago', 'Sadang Serang', 'Cirrrnbeuleurt', 'Cihampelas', 'Gede Bage', 'Gunung Batu', 'Sariladi'
    ]
})

G = nx.from_pandas_edgelist(df, 'from', 'to')

# %%
def graph_draw_coloring(data=None, sizes='Black', colormap=None):
    if data != None:
        cent = np.fromiter(data.values(), float)
        sizes = cent / np.max(cent) * 200
        
        normalize = mcolors.Normalize(vmin=cent.min(), vmax=cent.max())
        colormap = cm.Set1_r

        scalarmappaple = cm.ScalarMappable(norm=normalize, cmap=colormap)
        scalarmappaple.set_array(cent)
        
    plt.figure(figsize=(20, 12))
    nx.draw_kamada_kawai(G, with_labels=True, node_size=12000, font_color="white", font_weight='300',  node_color=sizes, cmap=colormap)
    plt.show()

# %%
graph_draw_coloring()

# %%
beetwen = nx.betweenness_centrality(G)

df = pd.DataFrame(sorted(beetwen.items(), key=lambda p: p[1], reverse=True), columns=['Kota', 'Nilai Betweenness'])
df
# Out:
#                     Kota  Nilai Betweenness
# 0           Kebon Kelapa           0.278986
# 1                   Dago           0.224638
# 2               Cicaheum           0.213768
# 3                Ciroyom           0.152174
# 4                St Hall           0.101449
# 5                 Ledeng           0.054348
# 6          Sadang Serang           0.054348
# 7           Stasiun Hall           0.036232
# 8        Cicaheum (aceh)           0.000000
# 9              Cibaduyut           0.000000
# 10          Leuwipanjang           0.000000
# 11             Bumi Asri           0.000000
# 12              Sarijadi           0.000000
# 13             Sarijadi            0.000000
# 14  Pasar lnduk Caringin           0.000000
# 15         Riung Bandung           0.000000
# 16        Margahayu Raya           0.000000
# 17      Panghegar Permai           0.000000
# 18            Dipatiukur           0.000000
# 19              Caringin           0.000000
# ...

# %%
graph_draw_coloring(beetwen)

# %%
degree = nx.degree_centrality(G)

df = pd.DataFrame(sorted(degree.items(), key=lambda p: p[1], reverse=True), columns=['Kota', 'Nilai Degree'])
df
# Out:
#                     Kota  Nilai Degree
# 0           Kebon Kelapa      0.208333
# 1           Stasiun Hall      0.208333
# 2               Cicaheum      0.166667
# 3                   Dago      0.166667
# 4                Ciroyom      0.166667
# 5                 Ledeng      0.125000
# 6          Sadang Serang      0.083333
# 7                St Hall      0.083333
# 8        Cicaheum (aceh)      0.041667
# 9              Cibaduyut      0.041667
# 10          Leuwipanjang      0.041667
# 11             Bumi Asri      0.041667
# 12              Sarijadi      0.041667
# 13             Sarijadi       0.041667
# 14  Pasar lnduk Caringin      0.041667
# 15         Riung Bandung      0.041667
# 16        Margahayu Raya      0.041667
# 17      Panghegar Permai      0.041667
# 18            Dipatiukur      0.041667
# 19              Caringin      0.041667
# 20        Cirrrnbeuleurt      0.041667
# 21            Cihampelas      0.041667
# 22             Gede Bage      0.041667
# ...

# %%
graph_draw_coloring(degree)

# %% [markdown]
# kebon kelada dan stasiun hall memiliki nilai degree centrality dan betweenness centrality yang paling tinggi, disusul ladeng dan seterusnya
